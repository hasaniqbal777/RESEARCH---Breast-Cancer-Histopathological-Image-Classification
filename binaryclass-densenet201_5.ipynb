# %% [markdown]
# # Importing Libraries

# %%
import gc
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm

from keras import layers
from keras.layers import Dense,Dropout,Activation,Add,MaxPooling2D,Conv2D,Flatten,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.utils.np_utils import to_categorical
from keras.models import Sequential

from keras import backend as K
from tensorflow.keras.applications import ResNet50, MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.compat.v1 import logging
logging.set_verbosity(logging.ERROR)

# %%
# Importing Data
data = pd.read_csv('../input/breakhis/Folds.csv')

# Image Directory
img_dir = '../input/breakhis/BreaKHis_v1/'

# Class Labels
class_names = ['benign', 'malignant']

# %% [markdown]
# # Data Pre-processing

# %%
# Renaming Column
if 'path' not in data.columns:
    data = data.rename(columns={'filename':'path'})

# Adding Columns with useful data
if 'label' or 'label_int' or 'filename' not in data.columns:
    data['label'] = data.path.apply(lambda x: x.split('/')[3])
    data['label_int'] = data.label.apply(lambda x: class_names.index(x))
    data['filename'] = data.path.apply(lambda x: x.split('/')[-1])

# Printing Useful information
print("Data Shape: ", data.shape)
print("Folds: ", data.fold.unique())
print("Magnifications: ", data.mag.unique())
print("Labels: ", data.label.unique(), data.label_int.unique())

print("Dataset:")
data.head(3)
# Out:
# Data Shape:  (39545, 7)
# Folds:  [1 2 3 4 5]
# Magnifications:  [100 200  40 400]
# Labels:  ['benign' 'malignant'] [0 1]
# Dataset:
#    fold  mag    grp                                               path  \
# 0     1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 1     1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 2     1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
#
#     label  label_int                        filename
# 0  benign          0  SOB_B_A-14-22549AB-100-001.png
# 1  benign          0  SOB_B_A-14-22549AB-100-002.png
# 2  benign          0  SOB_B_A-14-22549AB-100-003.png

# %% [markdown]
# ### Visualizing Label Counts

# %%
ax = sns.displot(data=data.iloc[0:7909], x='label')
print('Count of Benign    : ', data[data.label == 'benign'].label.count()/5)
print('Count of Malignant : ', data[data.label == 'malignant'].label.count()/5)
# Out:
# Count of Benign    :  2480.0
# Count of Malignant :  5429.0

# %% [markdown]
# ### Categorizing Data using Magnifications

# %%
# Plotting Data for all magnifications
ax = sns.displot(data=data.iloc[0:7909], x='label', col='mag')

# Data Dict
data_dict = {}

# Categorizing for all mags
for mag in data['mag'].unique():
    data_dict[mag]=data.loc[data['mag'] == mag].copy()
    print('Magnification:', mag)
    print(data_dict[mag].label.value_counts()/5, "\n")
# Out:
# Magnification: 100
# malignant    1437.0
# benign        644.0
# Name: label, dtype: float64
#
# Magnification: 200
# malignant    1390.0
# benign        623.0
# Name: label, dtype: float64
#
# Magnification: 40
# malignant    1370.0
# benign        625.0
# Name: label, dtype: float64
#
# Magnification: 400
# malignant    1232.0
# benign        588.0
# Name: label, dtype: float64

# %% [markdown]
# ### Load and View Images

# %%
img_width = 224
img_height = 224
dim = (img_width, img_height)

# Iterating on Mags
for mag in data['mag'].unique():
    # Initializing images column
    data_dict[mag]['img_read'] = np.nan
    data_dict[mag]['img_read'] = data_dict[mag]['img_read'].astype(object)

    # Printing Info
    print("[INFO] Importing Images for Magnification",mag)

    # Iterating on all rows and reading image data
    for index, row in tqdm(data_dict[mag].iterrows(), total=data_dict[mag].shape[0]):
        img = cv2.imread(img_dir + row.path)
        if img.shape != (img_width, img_height, 3):
            img = cv2.resize(img, dim)
        data_dict[mag].at[index, 'img_read'] = img
# Out:
# [INFO] Importing Images for Magnification 100
# 100%|██████████| 10405/10405 [02:07<00:00, 81.45it/s]
# [INFO] Importing Images for Magnification 200
# 100%|██████████| 10065/10065 [02:16<00:00, 73.52it/s]
# [INFO] Importing Images for Magnification 40
# 100%|██████████| 9975/9975 [02:15<00:00, 73.39it/s]
# [INFO] Importing Images for Magnification 400
# 100%|██████████| 9100/9100 [02:04<00:00, 73.11it/s]

# %%
row = 1
col = 4
per_mag = 4

for mag in data['mag'].unique():
    fig, axes = plt.subplots(row, col, figsize=(3.5*col,2*row))
    for images, labels, i in zip(data_dict[mag].sample(per_mag).iloc[:, 7],
                                 data_dict[mag].sample(per_mag).iloc[:, 4],
                                 range(per_mag)):
        ax = axes[i]
        ax.imshow(images)
        ax.set_title(labels+" - x"+str(mag))
        ax.axis("off") 
    plt.show()

# %%
EPOCHS = 10
INIT_LR = 1e-4
BATCH_SIZE = 16
INPUT_SHAPE = (224,224,3)

# %%
def build_model(backbone, lr=INIT_LR):
    model = Sequential()
    model.add(backbone)
    model.add(Conv2D(16, (3, 3), padding="valid", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"))
    model.add(Conv2D(32, (3, 3), padding="valid", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"))
    model.add(Conv2D(64, (3, 3), padding="valid", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Dense(2, activation='softmax'))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=Adam(learning_rate=lr),
                  metrics=['accuracy'])
    
    return model

# %%
# Early stop to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %%
datagen = ImageDataGenerator(rescale=1 / 255.0,
                              rotation_range=20,
                              zoom_range=0.05,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              shear_range=0.05,
                              horizontal_flip=True,
                              vertical_flip=True,
                              fill_mode="nearest")

# %%
def Train(mag, fold):
    # Train Data
    X_train = np.stack(data_dict[mag][(data_dict[mag]["fold"]==fold) & (data_dict[mag]["grp"]=="train")].img_read.to_list())
    y_train = data_dict[mag][(data_dict[mag]["fold"]==fold) & (data_dict[mag]["grp"]=="train")].label_int.to_list()
    y_train = to_categorical(y_train, num_classes= 2)

    # Test Data
    X_test = np.stack(data_dict[mag][(data_dict[mag]["fold"]==fold) & (data_dict[mag]["grp"]=="test")].img_read.to_list())
    y_test = data_dict[mag][(data_dict[mag]["fold"]==fold) & (data_dict[mag]["grp"]=="test")].label_int.to_list()

    # Validation Data
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=69)
    
    # Initializing Model
    K.clear_session()
    gc.collect()
    DenseNet201_model = DenseNet201(weights='imagenet',
                                    include_top=False,
                                    input_shape=INPUT_SHAPE)
    model = build_model(DenseNet201_model , lr = INIT_LR)
    
    print("--------------------------------------------------------------------------------------------")
    print("                               [INFO] Training Model")
    print("--------------------------------------------------------------------------------------------")
    
    # Fit Model
    history = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
                         steps_per_epoch=X_train.shape[0] / BATCH_SIZE,
                         epochs= EPOCHS,
                         validation_data=(X_val/255, y_val),
                         callbacks=[early_stop],
                         verbose=1)
    
    print("--------------------------------------------------------------------------------------------")
    print("                               [INFO] Evaluating Model")
    print("--------------------------------------------------------------------------------------------")
    # Evaluate model
    model.evaluate(X_val/255, y_val)

    y_pred = model.predict(X_test/255)
    y_pred = np.argmax(y_pred,axis=1)
    
    return model, history, y_test, y_pred

# %%
def History_metrics(history):    
    sns.set()

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)

    #accuracy plot
    plt.plot(epochs, accuracy, color='b', label='Training Accuracy')
    plt.plot(epochs, val_accuracy, color='r', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    plt.figure()
    #loss plot
    plt.plot(epochs, loss, color='g', label='Training Loss')
    plt.plot(epochs, val_loss, color='y', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
def Model_report(y_test, y_pred):
    sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, fmt='g')
    plt.xlabel("Predicted Class")
    plt.ylabel("Actual Class")
    print(classification_report(y_test, y_pred))
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# %%
mag_acc=np.empty((4,1))

# %% [markdown]
# # Magnification: 100x

# %%
mag =100

# %% [markdown]
# ## Fold 5

# %%
m, history, y_test, y_pred = Train(mag, 5)
# Out:
# --------------------------------------------------------------------------------------------
#                                [INFO] Training Model
# --------------------------------------------------------------------------------------------
# Epoch 1/10
# 55/55 [==============================] - 37s 315ms/step - loss: 0.7354 - accuracy: 0.5873 - val_loss: 0.6465 - val_accuracy: 0.6742
# Epoch 2/10
# 55/55 [==============================] - 14s 248ms/step - loss: 0.5864 - accuracy: 0.7483 - val_loss: 0.5771 - val_accuracy: 0.6923
# Epoch 3/10
# 55/55 [==============================] - 14s 244ms/step - loss: 0.4803 - accuracy: 0.8390 - val_loss: 0.6407 - val_accuracy: 0.6697
# Epoch 4/10
# 55/55 [==============================] - 14s 257ms/step - loss: 0.3533 - accuracy: 0.9082 - val_loss: 0.4739 - val_accuracy: 0.7466
# Epoch 5/10
# 55/55 [==============================] - 14s 250ms/step - loss: 0.3128 - accuracy: 0.9252 - val_loss: 0.3710 - val_accuracy: 0.8054
# Epoch 6/10
# 55/55 [==============================] - 14s 256ms/step - loss: 0.3133 - accuracy: 0.9184 - val_loss: 0.3545 - val_accuracy: 0.8100
# Epoch 7/10
# 55/55 [==============================] - 14s 248ms/step - loss: 0.2450 - accuracy: 0.9512 - val_loss: 0.2454 - val_accuracy: 0.8869
# Epoch 8/10
# 55/55 [==============================] - 14s 257ms/step - loss: 0.2103 - accuracy: 0.9580 - val_loss: 0.2094 - val_accuracy: 0.9050
# Epoch 9/10
# 55/55 [==============================] - 14s 245ms/step - loss: 0.2033 - accuracy: 0.9535 - val_loss: 0.1146 - val_accuracy: 0.9819
# Epoch 10/10
# 55/55 [==============================] - 15s 264ms/step - loss: 0.2244 - accuracy: 0.9478 - val_loss: 0.1589 - val_accuracy: 0.9548
# --------------------------------------------------------------------------------------------
#                                [INFO] Evaluating Model
# --------------------------------------------------------------------------------------------
# 7/7 [==============================] - 1s 93ms/step - loss: 0.1589 - accuracy: 0.9548

# %%
History_metrics(history)

# %%
mag_acc[0] = Model_report(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.60      0.71       250
#            1       0.82      0.94      0.88       467
#
#     accuracy                           0.83       717
#    macro avg       0.83      0.77      0.79       717
# weighted avg       0.83      0.83      0.82       717

# %%
# Save the model to disk
#print("[INFO] Serializing network...")
#model100.save("models/trained_bin_100_1")

# %% [markdown]
# # Magnification: 200x

# %%
mag = 200

# %% [markdown]
# ## Fold 5

# %%
m, history, y_test, y_pred = Train(mag, 5)
# Out:
# --------------------------------------------------------------------------------------------
#                                [INFO] Training Model
# --------------------------------------------------------------------------------------------
# Epoch 1/10
# 62/62 [==============================] - 39s 315ms/step - loss: 0.6252 - accuracy: 0.7062 - val_loss: 0.5327 - val_accuracy: 0.7791
# Epoch 2/10
# 62/62 [==============================] - 16s 253ms/step - loss: 0.4741 - accuracy: 0.8209 - val_loss: 0.4652 - val_accuracy: 0.7791
# Epoch 3/10
# 62/62 [==============================] - 15s 248ms/step - loss: 0.3781 - accuracy: 0.8783 - val_loss: 0.3812 - val_accuracy: 0.8514
# Epoch 4/10
# 62/62 [==============================] - 17s 272ms/step - loss: 0.3187 - accuracy: 0.9085 - val_loss: 0.3734 - val_accuracy: 0.8153
# Epoch 5/10
# 62/62 [==============================] - 15s 245ms/step - loss: 0.2503 - accuracy: 0.9507 - val_loss: 0.2622 - val_accuracy: 0.8835
# Epoch 6/10
# 62/62 [==============================] - 15s 245ms/step - loss: 0.2558 - accuracy: 0.9356 - val_loss: 0.3600 - val_accuracy: 0.8956
# Epoch 7/10
# 62/62 [==============================] - 16s 256ms/step - loss: 0.2413 - accuracy: 0.9427 - val_loss: 0.1782 - val_accuracy: 0.9518
# Epoch 8/10
# 62/62 [==============================] - 16s 253ms/step - loss: 0.2107 - accuracy: 0.9517 - val_loss: 0.0972 - val_accuracy: 0.9759
# Epoch 9/10
# 62/62 [==============================] - 16s 262ms/step - loss: 0.2164 - accuracy: 0.9517 - val_loss: 0.2175 - val_accuracy: 0.9237
# Epoch 10/10
# 62/62 [==============================] - 16s 254ms/step - loss: 0.2051 - accuracy: 0.9497 - val_loss: 0.1010 - val_accuracy: 0.9839
# --------------------------------------------------------------------------------------------
#                                [INFO] Evaluating Model
# --------------------------------------------------------------------------------------------
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1010 - accuracy: 0.9839

# %%
History_metrics(history)

# %%
mag_acc[1] = Model_report(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84       273
#            1       0.90      0.93      0.92       497
#
#     accuracy                           0.89       770
#    macro avg       0.89      0.88      0.88       770
# weighted avg       0.89      0.89      0.89       770

# %%
# Save the model to disk
#print("[INFO] Serializing network...")
#model200.save("models/trained_bin_200_1")

# %% [markdown]
# # Magnification: 40x

# %%
mag = 40

# %% [markdown]
# ## Fold 5

# %%
m, history, y_test, y_pred = Train(mag, 5)
# Out:
# --------------------------------------------------------------------------------------------
#                                [INFO] Training Model
# --------------------------------------------------------------------------------------------
# Epoch 1/10
# 61/61 [==============================] - 40s 340ms/step - loss: 0.7447 - accuracy: 0.5861 - val_loss: 0.5984 - val_accuracy: 0.7049
# Epoch 2/10
# 61/61 [==============================] - 15s 246ms/step - loss: 0.5610 - accuracy: 0.7418 - val_loss: 0.4704 - val_accuracy: 0.7951
# Epoch 3/10
# 61/61 [==============================] - 16s 256ms/step - loss: 0.4468 - accuracy: 0.8268 - val_loss: 0.4768 - val_accuracy: 0.7910
# Epoch 4/10
# 61/61 [==============================] - 16s 258ms/step - loss: 0.3473 - accuracy: 0.8955 - val_loss: 0.3466 - val_accuracy: 0.8484
# Epoch 5/10
# 61/61 [==============================] - 16s 254ms/step - loss: 0.2937 - accuracy: 0.9211 - val_loss: 0.2590 - val_accuracy: 0.8934
# Epoch 6/10
# 61/61 [==============================] - 15s 252ms/step - loss: 0.2404 - accuracy: 0.9457 - val_loss: 0.1824 - val_accuracy: 0.9426
# Epoch 7/10
# 61/61 [==============================] - 16s 261ms/step - loss: 0.2465 - accuracy: 0.9488 - val_loss: 0.2100 - val_accuracy: 0.9057
# Epoch 8/10
# 61/61 [==============================] - 15s 250ms/step - loss: 0.2304 - accuracy: 0.9436 - val_loss: 0.1249 - val_accuracy: 0.9795
# Epoch 9/10
# 61/61 [==============================] - 16s 253ms/step - loss: 0.1874 - accuracy: 0.9703 - val_loss: 0.1262 - val_accuracy: 0.9754
# Epoch 10/10
# 61/61 [==============================] - 15s 247ms/step - loss: 0.1868 - accuracy: 0.9641 - val_loss: 0.1436 - val_accuracy: 0.9795
# --------------------------------------------------------------------------------------------
#                                [INFO] Evaluating Model
# --------------------------------------------------------------------------------------------
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1436 - accuracy: 0.9795

# %%
History_metrics(history)

# %%
mag_acc[2] = Model_report(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.80       270
#            1       0.91      0.85      0.88       505
#
#     accuracy                           0.85       775
#    macro avg       0.83      0.85      0.84       775
# weighted avg       0.86      0.85      0.85       775

# %%
# Save the model to disk
#print("[INFO] Serializing network...")
#model40.save("models/trained_bin_40_1")

# %% [markdown]
# # Magnification: 400x

# %%
mag = 400

# %% [markdown]
# ## Fold 5

# %%
m, history, y_test, y_pred = Train(mag, 5)
# Out:
# --------------------------------------------------------------------------------------------
#                                [INFO] Training Model
# --------------------------------------------------------------------------------------------
# Epoch 1/10
# 55/55 [==============================] - 37s 311ms/step - loss: 0.7017 - accuracy: 0.6247 - val_loss: 0.5760 - val_accuracy: 0.7285
# Epoch 2/10
# 55/55 [==============================] - 14s 250ms/step - loss: 0.5809 - accuracy: 0.7290 - val_loss: 0.5396 - val_accuracy: 0.6968
# Epoch 3/10
# 55/55 [==============================] - 14s 248ms/step - loss: 0.4451 - accuracy: 0.8345 - val_loss: 0.6632 - val_accuracy: 0.6923
# Epoch 4/10
# 55/55 [==============================] - 15s 262ms/step - loss: 0.3827 - accuracy: 0.8832 - val_loss: 0.4795 - val_accuracy: 0.7421
# Epoch 5/10
# 55/55 [==============================] - 14s 251ms/step - loss: 0.3128 - accuracy: 0.9093 - val_loss: 0.5150 - val_accuracy: 0.7466
# Epoch 6/10
# 55/55 [==============================] - 14s 252ms/step - loss: 0.2896 - accuracy: 0.9229 - val_loss: 0.2335 - val_accuracy: 0.8959
# Epoch 7/10
# 55/55 [==============================] - 15s 265ms/step - loss: 0.2698 - accuracy: 0.9399 - val_loss: 0.1923 - val_accuracy: 0.9457
# Epoch 8/10
# 55/55 [==============================] - 14s 253ms/step - loss: 0.2516 - accuracy: 0.9422 - val_loss: 0.1396 - val_accuracy: 0.9683
# Epoch 9/10
# 55/55 [==============================] - 15s 268ms/step - loss: 0.2252 - accuracy: 0.9433 - val_loss: 0.1267 - val_accuracy: 0.9729
# Epoch 10/10
# 55/55 [==============================] - 14s 250ms/step - loss: 0.2057 - accuracy: 0.9569 - val_loss: 0.1138 - val_accuracy: 0.9774
# --------------------------------------------------------------------------------------------
#                                [INFO] Evaluating Model
# --------------------------------------------------------------------------------------------
# 7/7 [==============================] - 1s 91ms/step - loss: 0.1138 - accuracy: 0.9774

# %%
History_metrics(history)

# %%
mag_acc[3] = Model_report(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79       250
#            1       0.89      0.88      0.89       467
#
#     accuracy                           0.85       717
#    macro avg       0.84      0.84      0.84       717
# weighted avg       0.86      0.85      0.86       717

# %%
# Save the model to disk
#print("[INFO] Serializing network...")
#model400.save("models/trained_bin_400_1")
